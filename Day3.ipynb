# %%
from matplotlib import pyplot
roll_num = [1,2,3,4,5,6,7,8,9]
marks = [55,75,96,75,36,45,87,99,100]
pyplot.plot(roll_num,marks,'b')
pyplot.show()

# %% [markdown]
# Scatter Graph

# %%
from matplotlib import pyplot
roll_num = [1,2,3,4,5,6,7,8,9]
marks = [55,75,96,75,36,45,87,99,100]
pyplot.scatter(roll_num,marks)
pyplot.show()

# %% [markdown]
# Histogram

# %%
from matplotlib import pyplot
marks = [55,75,96,75,36,45,87,99,100]
pyplot.hist(marks,bins = 7)
pyplot.show()

# %% [markdown]
# Bar chart

# %%
import numpy as np
import matplotlib.pyplot
city = ('Pune','Etawa','Meerut','Gorakpur','Prayagraj','Bhopal')
y_val = np.arange(len(city))
rank = [4,7,1,3,2,5]
pyplot.bar(y_val,rank,align='center')
pyplot.xticks(y_val, city)
pyplot.ylabel('Rank')
pyplot.title('City')
pyplot.show()

# %%
from matplotlib import pyplot
roll_num = [1,2,3,4,5,6,7,8,9]
marks = [55,75,96,75,36,45,87,99,100]
attendace = [25,75,86,74,85,25,35,63,29]
pyplot.plot(roll_num,marks,color = 'green', label = 'Marks')
pyplot.plot(roll_num,attendace,color = 'blue', label = 'Attendance')
pyplot.legend(loc='upper left',frameon=True)
pyplot.show()

# %% [markdown]
# Pie chart

# %%
import numpy as np
import matplotlib.pyplot
city = ('Pune','Etawa','Meerut','Gorakpur','Prayagraj','Bhopal')
rank = [4,7,1,3,2,5]
explode = (0.2,0,0,0,0,0)
colors = ['yellowgreen','pink','purple','grey','red','orange']
pyplot.pie(rank,explode=explode,labels=city,colors=colors,autopct='%1.1f%%',shadow=True,startangle=120)
pyplot.axis('equal')
pyplot.show()

# %%
import numpy as np
import matplotlib.pyplot
city = ('MODI','BHUVI','PRATHAM','MAYAWATI','MAMTA','YOGI')
rank = [6,7,1,5,2,3]
explode = (0.2,0,0,0,0,0)
colors = ['yellowgreen','pink','purple','grey','red','orange']
pyplot.pie(rank,explode=explode,labels=city,colors=colors,autopct='%1.1f%%',shadow=True,startangle=120)
pyplot.axis('equal')
pyplot.show()
