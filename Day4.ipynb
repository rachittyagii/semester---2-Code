# %% [markdown]
# Bellman Ford

# %%
import numpy as np
from scipy.sparse.csgraph import bellman_ford
from scipy.sparse import csr_matrix
arr=np.array([[0,1,2],[1,0,0],[2,0,0]])
newarr = csr_matrix(arr)
print(bellman_ford(newarr,return_predecessors=True,indices=0))
# Out:
# (array([0., 1., 2.]), array([-9999,     0,     0]))

# %% [markdown]
# Seaborn

# %%
import seaborn
import pandas
import matplotlib.pyplot as plt
c = pandas.read_csv(r'E:\DAY2\Data\Book1.csv')
print(c)
res = seaborn.scatterplot(x = 'Name', y = 'Age',data = c)
plt.show()
# Out:
#       Name  Age
# 0  pratham   19
# 1     yash   18
# 2   rachit   19
# 3  krishna   17
# 4    ayush   20
# 5    bhuvi   20
# 6  shubham   19
# 7    arpit   19
# 8  ujjawal   18

# %% [markdown]
# Inbuilt data set of sea born

# %%
import seaborn
seaborn.set(style='whitegrid')
fmri=seaborn.load_dataset('fmri')
seaborn.scatterplot(x='timepoint',y='signal',data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# Seaborn line.plot

# %%
import seaborn
seaborn.set(style='whitegrid')
fmri=seaborn.load_dataset('fmri')
seaborn.lineplot(x='timepoint',y='signal',data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
import seaborn
import pandas
import matplotlib.pyplot as plt
c = pandas.read_csv(r'E:\DAY2\Data\Book1.csv')
print(c)
res = seaborn.lineplot(x = 'Name', y = 'Age',data = c)
plt.show()
# Out:
#       Name  Age
# 0  pratham   19
# 1     yash   18
# 2   rachit   19
# 3  krishna   17
# 4    ayush   20
# 5    bhuvi   20
# 6  shubham   19
# 7    arpit   19
# 8  ujjawal   18

# %% [markdown]
# Categorical Scatter plot

# %%
import seaborn
import pandas
import matplotlib.pyplot as plt
csv = seaborn.load_dataset("tips")
res=seaborn.stripplot(x="tip",y="sex",data=csv,jitter=0.05)
plt.show()

# %%
import seaborn
import pandas
import matplotlib.pyplot as plt
c = pandas.read_csv(r'E:\DAY2\Data\Book2.csv')
print(c)
res = seaborn.catplot(x = 'total_bill', y = 'sex',data = c)
plt.show()
# Out:
#    total_bill   tip     sex smoker       day   time  size
# 0          10  1.01  female    Yes    Sunday  17:00   NaN
# 1          15  2.00    male     no  Saturday  18:00   NaN
# 2          14  5.00    male    yes    Friday  22:00   NaN
# 3          20  4.00  female    yes   Tuesday  21:00   NaN
# 4          17  5.00  female     no  Thursday  18:00   NaN

# %%
import seaborn
import pandas
import matplotlib.pyplot as plt
c = pandas.read_csv(r'E:\DAY2\Data\Book2.csv')
print(c)
res = seaborn.stripplot(x = 'total_bill', y = 'sex',data = c)
plt.show()
# Out:
#    total_bill   tip     sex smoker       day   time  size
# 0          10  1.01  female    Yes    Sunday  17:00   NaN
# 1          15  2.00    male     no  Saturday  18:00   NaN
# 2          14  5.00    male    yes    Friday  22:00   NaN
# 3          20  4.00  female    yes   Tuesday  21:00   NaN
# 4          17  5.00  female     no  Thursday  18:00   NaN

# %%
from tkinter import *
root = Tk()
root.title("Rachit Tyagi")
root.geometry('350x200')
root.mainloop()

# %%
import tkinter as tk
r = tk.Tk()
r.title('Rachit Tyagi')
button=tk.Button(text='Stop',width=25,command=r.destroy)
button.pack()
r.mainloop()

# %%
import tkinter
from tkinter import *
from tkinter import messagebox
top = tkinter.Tk()
top.title("Rachit Tyagi")
def helloCallBack():
    messagebox.showinfo("Hello Python","Hello World")
B=tkinter.Button(top,text="Hello",command=helloCallBack)
B.pack()
top.mainloop()

# %%
from tkinter import *
master = Tk()
master.title("Rachit Tyagi")
w=Canvas(master,width=40,height=60)
w.pack()
canvas_height=20
canvas_width=200
y=int(canvas_height/2)
w.create_line(0,y,canvas_width,y)
mainloop()

# %%
from tkinter import *
master = Tk()
master.title("Rachit Tyagi")
w=Canvas(master,width=2000,height=20,bg='black')
w.pack()
canvas_height=20
canvas_width=200
y=int(canvas_height/2)
w.create_line(0,y,canvas_width,y)
mainloop()
